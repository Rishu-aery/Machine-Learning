# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishu-aery/Machine-Learning/blob/main/pca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
from sklearn.datasets import load_digits

# %%
digits = load_digits()
features = digits.data
target = digits.target

# %%
for i,featuresvalues in enumerate(features):
  print(i,featuresvalues)
# Out:
# Streaming output truncated to the last 5000 lines.
# 547 [ 0.  0.  2. 10. 16. 11.  1.  0.  0.  0. 13. 13. 10. 16.  8.  0.  0.  4.
#  14.  1.  8. 14.  1.  0.  0.  4. 15. 12. 15.  8.  0.  0.  0.  0.  6.  7.
#  14.  5.  0.  0.  0.  1.  2.  0. 12.  5.  0.  0.  0.  8. 15.  6. 13.  4.
#   0.  0.  0.  0.  5. 11. 16.  3.  0.  0.]
# 548 [ 0.  0. 13. 16. 16. 16. 13.  0.  0.  4. 16.  9.  8.  5.  4.  0.  0.  9.
#  15.  7.  8.  2.  0.  0.  0. 11. 16. 16. 14. 15.  1.  0.  0.  1.  3.  0.
#   4. 16.  4.  0.  0.  0.  0.  0.  8. 14.  0.  0.  0.  0. 11.  8. 16.  6.
#   0.  0.  0.  1. 15. 16. 10.  0.  0.  0.]
# 549 [ 0.  0.  9.  8. 12. 13.  1.  0.  0.  3. 15.  8.  5.  4.  0.  0.  0.  6.
#   9.  2.  6.  2.  0.  0.  0.  6. 16. 14.  9. 13.  4.  0.  0.  2.  7.  0.
#   0.  7.  8.  0.  0.  0.  0.  0.  0.  7. 10.  0.  0.  0.  8.  5.  6. 14.
#   3.  0.  0.  0. 10. 14. 15.  5.  0.  0.]
# 550 [ 0.  0.  2. 13. 16.  8.  0.  0.  0.  0. 11. 16.  6.  2.  0.  0.  0.  2.
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = scaler.fit_transform(features)
x
# Out:
# array([[ 0.        , -0.33501649, -0.04308102, ..., -1.14664746,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649, -1.09493684, ...,  0.54856067,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649, -1.09493684, ...,  1.56568555,
#          1.6951369 , -0.19600752],
#        ...,
#        [ 0.        , -0.33501649, -0.88456568, ..., -0.12952258,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649, -0.67419451, ...,  0.8876023 ,
#         -0.5056698 , -0.19600752],
#        [ 0.        , -0.33501649,  1.00877481, ...,  0.8876023 ,
#         -0.26113572, -0.19600752]])

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
pca = PCA().fit(features)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('components')
plt.ylabel('explained variance')
# Out:
# Text(0, 0.5, 'explained variance')

# %%
pca = PCA(n_components=2)
projected = pca.fit_transform(features)
print(digits.data.shape)
print(projected.shape)
# Out:
# (1797, 64)
# (1797, 2)

# %%
df = pd.DataFrame(data = projected ,columns=['pc1','pc2'])
df['y'] = target
df
# Out:
#             pc1        pc2  y
# 0     -1.259466  21.274884  0
# 1      7.957609 -20.768687  1
# 2      6.991923  -9.955989  2
# 3    -15.906109   3.332487  3
# 4     23.306869   4.269050  4
# ...         ...        ... ..
# 1792 -14.606634  13.344154  9
# 1793   6.464568  20.567324  0
# 1794  10.801286  -6.960259  8
# 1795  -4.872102  12.423956  9
# 1796  -0.344387   6.365538  8
#
# [1797 rows x 3 columns]

# %%
plt.scatter(projected[:,0],projected [:,1])
plt.xlabel('component1')
plt.ylabel('component2')
# Out:
# Text(0, 0.5, 'component2')

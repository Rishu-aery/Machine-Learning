# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishu-aery/Machine-Learning/blob/main/Titanic_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
dataset = pd.read_csv(url)

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
dataset.shape
# Out:
# (891, 12)

# %%
dataset
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
v = dataset.drop(['Name','Sex','Ticket','Cabin','Embarked'],axis=1)

# %%
v
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
from sklearn.impute import  SimpleImputer
imr = SimpleImputer(missing_values=np.nan,strategy='mean')
imputed = imr.fit(v)
imp = imputed.transform(v)
Dataframe = pd.DataFrame(imp,columns=v.columns)

# %%
from sklearn.model_selection import train_test_split
a = Dataframe.iloc[:,Dataframe.columns!= 'Survived']
b = Dataframe.iloc[:,1]
xtrain,xtest,ytrain,ytest = train_test_split(a,b,test_size=.3,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(xtrain,ytrain)
pred = clf.predict(xtest)
org = ytest
score = clf.score(xtest,ytest)
print(score)
# Out:
# 0.6716417910447762

# %%
import matplotlib.pyplot as plt
plt.plot(pred)

# %%
plt.plot(org)

# %%
plt.scatter(pred,org)
